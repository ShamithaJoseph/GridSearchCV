# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_female','smoker_no']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'bootstrap': [True],
    'max_depth': [6, 9, 10, 11],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [2,4, 6],
    'n_estimators': [1, 10, 50, 100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, cv = 3, n_jobs = -1, verbose = 2)
grid.fit(independent,dependent)
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# C:\Users\shami\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [6, 9, 10, 11],
#                          'max_features': [2, 3], 'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [1, 10, 50, 100]},
#              verbose=2)

# %%
print(grid.best_params_)
# Out:
# {'bootstrap': True, 'max_depth': 6, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 50}

# %%
df = pd.DataFrame(grid.cv_results_)
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.026662      0.009985         0.007997        0.000008
# 1         0.055999      0.006539         0.008000        0.000016
# 2         0.199990      0.006531         0.018670        0.003766
# 3         0.381200      0.013650         0.026678        0.003778
# 4         0.016006      0.006531         0.007997        0.000001
# ..             ...           ...              ...             ...
# 283       0.394322      0.003091         0.016938        0.002209
# 284       0.012995      0.000818         0.006666        0.000465
# 285       0.050338      0.002862         0.007663        0.000468
# 286       0.208320      0.008058         0.012669        0.002051
# 287       0.307909      0.004644         0.013334        0.000475
#
#     param_bootstrap param_max_depth param_max_features param_min_samples_leaf  \
# 0              True               6                  2                      3
# 1              True               6                  2                      3
# 2              True               6                  2                      3
# 3              True               6                  2                      3
# 4              True               6                  2                      3
# ..              ...             ...                ...                    ...
# 283            True              11                  3                      5
# 284            True              11                  3                      5
# 285            True              11                  3                      5
# 286            True              11                  3                      5
# 287            True              11                  3                      5
#
#     param_min_samples_split param_n_estimators  \
# 0                         2                  1
# 1                         2                 10
# 2                         2                 50
# 3                         2                100
# 4                         4                  1
# ..                      ...                ...
# 283                       4                100
# 284                       6                  1
# 285                       6                 10
# 286                       6                 50
# 287                       6                100
#
#                                                 params  split0_test_score  \
# 0    {'bootstrap': True, 'max_depth': 6, 'max_featu...           0.749650
# 1    {'bootstrap': True, 'max_depth': 6, 'max_featu...           0.852132
# 2    {'bootstrap': True, 'max_depth': 6, 'max_featu...           0.857383
# 3    {'bootstrap': True, 'max_depth': 6, 'max_featu...           0.858697
# 4    {'bootstrap': True, 'max_depth': 6, 'max_featu...           0.728151
# ..                                                 ...                ...
# 283  {'bootstrap': True, 'max_depth': 11, 'max_feat...           0.864994
# 284  {'bootstrap': True, 'max_depth': 11, 'max_feat...           0.855637
# 285  {'bootstrap': True, 'max_depth': 11, 'max_feat...           0.856914
# 286  {'bootstrap': True, 'max_depth': 11, 'max_feat...           0.861980
# 287  {'bootstrap': True, 'max_depth': 11, 'max_feat...           0.863839
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             0.844294           0.791898         0.795281        0.038713
# 1             0.825349           0.829821         0.835767        0.011715
# 2             0.820807           0.834574         0.837588        0.015083
# 3             0.836973           0.832624         0.842765        0.011405
# 4             0.825418           0.794774         0.782781        0.040604
# ..                 ...                ...              ...             ...
# 283           0.858712           0.838853         0.854186        0.011142
# 284           0.765900           0.730328         0.783955        0.052726
# 285           0.851739           0.822223         0.843625        0.015281
# 286           0.857910           0.839736         0.853208        0.009671
# 287           0.856886           0.837240         0.852655        0.011264
#
#      rank_test_score
# 0                238
# 1                189
# 2                186
# 3                131
# 4                254
# ..               ...
# 283               19
# 284              252
# 285              120
# 286               30
# 287               35
#
# [288 rows x 17 columns]

# %%
age_input=int(input("Age: "))
sex_female_input=int(input("sex_female 1 or  : "))
bmi_input=float(input("bmi: "))
children_input=int(input("children:"))
smoker_no_input=int(input("smoker_no 1 or 0"))
# Out:
# Age: 30
# sex_female 1 or  : 1
# bmi: 29
# children:1
# smoker_no 1 or 00

# %%
future_prediction=grid.predict([[age_input,sex_female_input,bmi_input,children_input,smoker_no_input]])
print("future prediction= {}". format(future_prediction))
# Out:
# future prediction= [17940.92329766]
# C:\Users\shami\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
