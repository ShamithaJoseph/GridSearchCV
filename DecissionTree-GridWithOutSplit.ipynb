# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_female','smoker_no']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, cv = 3, n_jobs = -1, verbose = 2)
grid.fit(independent,dependent)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              verbose=2)

# %%
print(grid.best_params_)
# Out:
# {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %%
df = pd.DataFrame(grid.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018458      0.002562         0.007993        0.001417
# 1        0.015329      0.001251         0.006668        0.000479
# 2        0.012333      0.001251         0.005666        0.000473
# 3        0.013328      0.001692         0.005672        0.000465
# 4        0.009003      0.002949         0.003993        0.001406
# 5        0.009664      0.002624         0.004354        0.001705
# 6        0.014661      0.002494         0.006003        0.000005
# 7        0.012330      0.002632         0.005006        0.000810
# 8        0.011319      0.001707         0.005681        0.000936
# 9        0.008665      0.000479         0.010661        0.005890
# 10       0.008659      0.000952         0.005008        0.000010
# 11       0.013324      0.003397         0.005344        0.000464
# 12       0.009993      0.001638         0.009008        0.002158
# 13       0.008993      0.000008         0.005335        0.000470
# 14       0.009334      0.000470         0.005324        0.000472
# 15       0.008665      0.001245         0.005342        0.000477
# 16       0.008341      0.000472         0.005672        0.000468
# 17       0.007989      0.000821         0.005673        0.000473
# 18       0.011996      0.000819         0.005335        0.000473
# 19       0.011667      0.000473         0.005333        0.000475
# 20       0.011329      0.002621         0.005665        0.000473
# 21       0.011001      0.000002         0.005331        0.000475
# 22       0.010998      0.000003         0.005675        0.000469
# 23       0.010999      0.000821         0.005325        0.000471
# 24       0.009330      0.000467         0.005337        0.000946
# 25       0.009329      0.000470         0.004997        0.000002
# 26       0.008327      0.001247         0.004996        0.000816
#
#    param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0             None                      1                       2
# 1             None                      1                       5
# 2             None                      1                      10
# 3             None                      2                       2
# 4             None                      2                       5
# 5             None                      2                      10
# 6             None                      4                       2
# 7             None                      4                       5
# 8             None                      4                      10
# 9                5                      1                       2
# 10               5                      1                       5
# 11               5                      1                      10
# 12               5                      2                       2
# 13               5                      2                       5
# 14               5                      2                      10
# 15               5                      4                       2
# 16               5                      4                       5
# 17               5                      4                      10
# 18              10                      1                       2
# 19              10                      1                       5
# 20              10                      1                      10
# 21              10                      2                       2
# 22              10                      2                       5
# 23              10                      2                      10
# 24              10                      4                       2
# 25              10                      4                       5
# 26              10                      4                      10
#
#                                                params  split0_test_score  \
# 0   {'max_depth': None, 'min_samples_leaf': 1, 'mi...           0.701343
# 1   {'max_depth': None, 'min_samples_leaf': 1, 'mi...           0.739491
# 2   {'max_depth': None, 'min_samples_leaf': 1, 'mi...           0.774931
# 3   {'max_depth': None, 'min_samples_leaf': 2, 'mi...           0.775506
# 4   {'max_depth': None, 'min_samples_leaf': 2, 'mi...           0.788599
# 5   {'max_depth': None, 'min_samples_leaf': 2, 'mi...           0.816950
# 6   {'max_depth': None, 'min_samples_leaf': 4, 'mi...           0.818521
# 7   {'max_depth': None, 'min_samples_leaf': 4, 'mi...           0.818521
# 8   {'max_depth': None, 'min_samples_leaf': 4, 'mi...           0.820613
# 9   {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...           0.845954
# 10  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...           0.845954
# 11  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...           0.845954
# 12  {'max_depth': 5, 'min_samples_leaf': 2, 'min_s...           0.857435
# 13  {'max_depth': 5, 'min_samples_leaf': 2, 'min_s...           0.857435
# 14  {'max_depth': 5, 'min_samples_leaf': 2, 'min_s...           0.857435
# 15  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...           0.856646
# 16  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...           0.856646
# 17  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...           0.856646
# 18  {'max_depth': 10, 'min_samples_leaf': 1, 'min_...           0.741761
# 19  {'max_depth': 10, 'min_samples_leaf': 1, 'min_...           0.758414
# 20  {'max_depth': 10, 'min_samples_leaf': 1, 'min_...           0.791433
# 21  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...           0.780836
# 22  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...           0.798765
# 23  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...           0.820413
# 24  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...           0.817357
# 25  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...           0.817357
# 26  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...           0.819453
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.657194           0.704883         0.687807        0.021695
# 1            0.726968           0.742109         0.736189        0.006607
# 2            0.773622           0.772020         0.773524        0.001190
# 3            0.758918           0.776331         0.770251        0.008021
# 4            0.767053           0.777441         0.777698        0.008798
# 5            0.793851           0.792138         0.800980        0.011314
# 6            0.813406           0.798659         0.810195        0.008421
# 7            0.813406           0.798662         0.810197        0.008419
# 8            0.817827           0.801462         0.813301        0.008448
# 9            0.837339           0.830843         0.838045        0.006189
# 10           0.850081           0.830843         0.842293        0.008269
# 11           0.849932           0.830843         0.842243        0.008223
# 12           0.850089           0.829679         0.845734        0.011742
# 13           0.850089           0.829679         0.845734        0.011742
# 14           0.849940           0.829679         0.845685        0.011724
# 15           0.856697           0.833441         0.848928        0.010951
# 16           0.856697           0.833441         0.848928        0.010951
# 17           0.856612           0.833441         0.848900        0.010931
# 18           0.711996           0.747134         0.733630        0.015454
# 19           0.752195           0.765173         0.758594        0.005300
# 20           0.786306           0.784113         0.787284        0.003067
# 21           0.791716           0.784262         0.785604        0.004542
# 22           0.790077           0.785892         0.791578        0.005362
# 23           0.803699           0.793493         0.805868        0.011097
# 24           0.817894           0.800705         0.811985        0.007979
# 25           0.817894           0.800709         0.811987        0.007978
# 26           0.821694           0.802681         0.814610        0.008484
#
#     rank_test_score
# 0                27
# 1                25
# 2                22
# 3                23
# 4                21
# 5                17
# 6                15
# 7                14
# 8                11
# 9                 9
# 10                7
# 11                8
# 12                4
# 13                4
# 14                6
# 15                1
# 16                1
# 17                3
# 18               26
# 19               24
# 20               19
# 21               20
# 22               18
# 23               16
# 24               13
# 25               12
# 26               10

# %%
age_input=int(input("Age: "))
sex_female_input=int(input("sex_female 1 or  : "))
bmi_input=float(input("bmi: "))
children_input=int(input("children:"))
smoker_no_input=int(input("smoker_no 1 or 0"))
# Out:
# Age: 30
# sex_female 1 or  : 1
# bmi: 29
# children:1
# smoker_no 1 or 00

# %%
future_prediction=grid.predict([[age_input,sex_female_input,bmi_input,children_input,smoker_no_input]])
print("future prediction= {}". format(future_prediction))
# Out:
# future prediction= [20231.520856]
# C:\Users\shami\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
